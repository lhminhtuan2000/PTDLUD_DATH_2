# %% [markdown]
# ## Nhóm PTDLUD#3
# 19120148 - Lê Huỳnh Minh Tuấn
#
# 19120341 - Phạm Nhựt Quang
#
# 19120687 - Ngô Quốc Toại
#
# 19120692 - Phạm Minh Trí

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# # EDA

# %%
# Đọc dữ liệu nguồn 1
df_1 = pd.read_csv("https://raw.githubusercontent.com/adishourya/Airbnb/master/new-york-city-airbnb-open-data/AB_NYC_2019.csv")
df_1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
# Đọc dữ liệu nguồn 2
df_2 = pd.read_csv("airbnb-listings_new-york.csv", sep=';', low_memory=False)
df_2.head()
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0  13494898  https://www.airbnb.com/rooms/13494898  20170502132028
# 1   7859723   https://www.airbnb.com/rooms/7859723  20170502132028
# 2    137558    https://www.airbnb.com/rooms/137558  20170502132028
# 3   3915771   https://www.airbnb.com/rooms/3915771  20170502132028
# 4   2537383   https://www.airbnb.com/rooms/2537383  20170502132028
#
#   Last Scraped                                              Name  \
# 0   2017-05-04  Modern 1BR apartment amazing location in Chelsea
# 1   2017-05-04                        Spacious Studio in Chelsea
# 2   2017-05-05                    MINIMALIST APT. HIGH-LINE AREA
# 3   2017-05-05                Furnished Studio with Loft CHELSEA
# 4   2017-05-05                    New York City - A Love Affair!
#
#                                              Summary  \
# 0  This modern apartment is full of New York char...
# 1  Large and very clean studio on a beautiful tre...
# 2                                                NaN
# 3  Lovely studio apartment in the heart of Manhat...
# 4  Charming, very quaint, sunny 1 bdrm apt., 4th ...
#
#                                                Space  \
# 0                                                NaN
# 1                                                NaN
# 2  This is the most charming place in the area. T...
# 3  This is an amazing studio right in the center ...
# 4  The apartment is a REAL one bedroom, unlike ma...
#
#                                          Description Experiences Offered  \
# 0  This modern apartment is full of New York char...                none
# 1  Large and very clean studio on a beautiful tre...                none
# 2  This is the most charming place in the area. T...                none
# 3  Lovely studio apartment in the heart of Manhat...                none
# 4  Charming, very quaint, sunny 1 bdrm apt., 4th ...                none
#
#                                Neighborhood Overview  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3  Chelsea, for those who don't know NYC, is amaz...  ...
# 4  Chelsa is one of the most sought after neighbo...  ...
#
#   Review Scores Communication Review Scores Location Review Scores Value  \
# 0                        10.0                   10.0                10.0
# 1                        10.0                   10.0                10.0
# 2                        10.0                   10.0                 9.0
# 3                        10.0                   10.0                 9.0
# 4                        10.0                   10.0                10.0
#
#   License Jurisdiction Names Cancellation Policy  \
# 0     NaN                NaN            flexible
# 1     NaN                NaN              strict
# 2     NaN                NaN              strict
# 3     NaN                NaN            moderate
# 4     NaN                NaN              strict
#
#   Calculated host listings count Reviews per Month  \
# 0                              1              0.29
# 1                              1              0.60
# 2                              1              0.20
# 3                              1              0.53
# 4                              1              0.98
#
#                             Geolocation  \
# 0  40.74032236139562,-74.00264894520818
# 1   40.74452858803597,-73.9998811278712
# 2     40.752836564513,-74.0071511604528
# 3  40.74461572374567,-74.00046825033714
# 4   40.74122935887343,-74.0026704259246
#
#                                             Features
# 0             Host Has Profile Pic,Is Location Exact
# 1  Host Has Profile Pic,Host Identity Verified,Is...
# 2             Host Has Profile Pic,Is Location Exact
# 3        Host Has Profile Pic,Host Identity Verified
# 4  Host Has Profile Pic,Host Identity Verified,Is...
#
# [5 rows x 89 columns]

# %% [markdown]
# ## Gộp 2 nguồn dữ liệu

# %%
# format thống nhất tên cột 2 nguồn dữ liệu
df_1.columns = (df_1.columns.str.upper())
df_2.columns = (df_2.columns.str.replace(' ', '_').str.upper())

# %%
# Lấy những cột chung ở 2 nguồn dữ liệu
selected_cols = df_1.columns.intersection(df_2.columns)
selected_cols
# print(df_1.columns.difference(df_2.columns))
# Out:
# Index(['ID', 'NAME', 'HOST_ID', 'HOST_NAME', 'NEIGHBOURHOOD', 'LATITUDE',
#        'LONGITUDE', 'ROOM_TYPE', 'PRICE', 'MINIMUM_NIGHTS',
#        'NUMBER_OF_REVIEWS', 'LAST_REVIEW', 'REVIEWS_PER_MONTH',
#        'CALCULATED_HOST_LISTINGS_COUNT', 'AVAILABILITY_365'],
#       dtype='object')

# %%
# Xoá các cột không cần thiết
selected_cols = selected_cols.drop(['NAME', 'HOST_NAME'])
selected_cols
# Out:
# Index(['ID', 'HOST_ID', 'NEIGHBOURHOOD', 'LATITUDE', 'LONGITUDE', 'ROOM_TYPE',
#        'PRICE', 'MINIMUM_NIGHTS', 'NUMBER_OF_REVIEWS', 'LAST_REVIEW',
#        'REVIEWS_PER_MONTH', 'CALCULATED_HOST_LISTINGS_COUNT',
#        'AVAILABILITY_365'],
#       dtype='object')

# %%
# Lọc các id đã có df_1 trong df_2
df_1_ids = set(df_1['ID'])
df_2 = df_2[[(id not in df_1_ids) for id in df_2['ID']]]

# %%
# Gộp 2 data frame
df = pd.concat([df_1[selected_cols], df_2[selected_cols]])
# Reset index
df.reset_index(inplace=True)
# Xoá index cũ
df.drop(columns=['index'], inplace=True)
df
# Out:
#              ID   HOST_ID  NEIGHBOURHOOD   LATITUDE  LONGITUDE  \
# 0          2539      2787     Kensington  40.647490 -73.972370
# 1          2595      2845        Midtown  40.753620 -73.983770
# 2          3647      4632         Harlem  40.809020 -73.941900
# 3          3831      4869   Clinton Hill  40.685140 -73.959760
# 4          5022      7192    East Harlem  40.798510 -73.943990
# ...         ...       ...            ...        ...        ...
# 60367   2495505  12505495    East Harlem  40.792284 -73.947239
# 60368     32329    139853   East Village  40.728953 -73.983767
# 60369  16367702  26498045  Alphabet City  40.720821 -73.979162
# 60370   1163484   1622421  Alphabet City  40.729144 -73.980603
# 60371   2022729   1319867  Alphabet City  40.723405 -73.982403
#
#              ROOM_TYPE  PRICE  MINIMUM_NIGHTS  NUMBER_OF_REVIEWS LAST_REVIEW  \
# 0         Private room  149.0               1                  9  2018-10-19
# 1      Entire home/apt  225.0               1                 45  2019-05-21
# 2         Private room  150.0               3                  0         NaN
# 3      Entire home/apt   89.0               1                270  2019-07-05
# 4      Entire home/apt   80.0              10                  9  2018-11-19
# ...                ...    ...             ...                ...         ...
# 60367     Private room   99.0               4                 23  2016-11-18
# 60368  Entire home/apt  160.0              14                  3  2016-08-19
# 60369     Private room   80.0               7                  0         NaN
# 60370  Entire home/apt  178.0               4                 75  2017-03-21
# 60371  Entire home/apt  222.0               2                132  2017-04-26
#
#        REVIEWS_PER_MONTH  CALCULATED_HOST_LISTINGS_COUNT  AVAILABILITY_365
# 0                   0.21                               6               365
# 1                   0.38                               2               355
# 2                    NaN                               1               365
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# ...                  ...                             ...               ...
# 60367               0.62                               2               342
# 60368               0.05                               1               341
# 60369                NaN                               1                 0
# 60370               1.59                               2               335
# 60371               3.21                               1               313
#
# [60372 rows x 13 columns]

# %%
# Kiểm tra dữ liệu trùng
df.duplicated().sum()
# Out:
# 0

# %%
# Kiểm tra missing values
df.isnull().sum()
# Out:
# ID                                    0
# HOST_ID                               0
# NEIGHBOURHOOD                      2215
# LATITUDE                              0
# LONGITUDE                             0
# ROOM_TYPE                             0
# PRICE                                72
# MINIMUM_NIGHTS                        0
# NUMBER_OF_REVIEWS                     0
# LAST_REVIEW                       12574
# REVIEWS_PER_MONTH                 12612
# CALCULATED_HOST_LISTINGS_COUNT        0
# AVAILABILITY_365                      0
# dtype: int64

# %%
corr = df.corr()
# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap = sns.diverging_palette(230, 20, as_cmap=True),
        annot = True,
        fmt=".2f",
        linewidth=.5)
# Out:
# <AxesSubplot: >

# %%
corr[corr > 0.3]
# Out:
#                                       ID   HOST_ID  LATITUDE  LONGITUDE  \
# ID                              1.000000  0.603185       NaN        NaN
# HOST_ID                         0.603185  1.000000       NaN        NaN
# LATITUDE                             NaN       NaN  1.000000   0.453951
# LONGITUDE                            NaN       NaN  0.453951   1.000000
# PRICE                                NaN       NaN       NaN        NaN
# MINIMUM_NIGHTS                       NaN       NaN       NaN        NaN
# NUMBER_OF_REVIEWS                    NaN       NaN       NaN        NaN
# REVIEWS_PER_MONTH                    NaN       NaN       NaN        NaN
# CALCULATED_HOST_LISTINGS_COUNT       NaN       NaN       NaN        NaN
# AVAILABILITY_365                     NaN       NaN       NaN        NaN
#
#                                 PRICE  MINIMUM_NIGHTS  NUMBER_OF_REVIEWS  \
# ID                                NaN             NaN                NaN
# HOST_ID                           NaN             NaN                NaN
# LATITUDE                          NaN             NaN                NaN
# LONGITUDE                         NaN             NaN                NaN
# PRICE                             1.0             NaN                NaN
# MINIMUM_NIGHTS                    NaN             1.0                NaN
# NUMBER_OF_REVIEWS                 NaN             NaN           1.000000
# REVIEWS_PER_MONTH                 NaN             NaN           0.539012
# CALCULATED_HOST_LISTINGS_COUNT    NaN             NaN                NaN
# AVAILABILITY_365                  NaN             NaN                NaN
#
#                                 REVIEWS_PER_MONTH  \
# ID                                            NaN
# HOST_ID                                       NaN
# LATITUDE                                      NaN
# LONGITUDE                                     NaN
# PRICE                                         NaN
# MINIMUM_NIGHTS                                NaN
# NUMBER_OF_REVIEWS                        0.539012
# REVIEWS_PER_MONTH                        1.000000
# CALCULATED_HOST_LISTINGS_COUNT                NaN
# AVAILABILITY_365                              NaN
#
#                                 CALCULATED_HOST_LISTINGS_COUNT  \
# ID                                                         NaN
# HOST_ID                                                    NaN
# LATITUDE                                                   NaN
# LONGITUDE                                                  NaN
# PRICE                                                      NaN
# MINIMUM_NIGHTS                                             NaN
# NUMBER_OF_REVIEWS                                          NaN
# REVIEWS_PER_MONTH                                          NaN
# CALCULATED_HOST_LISTINGS_COUNT                             1.0
# AVAILABILITY_365                                           NaN
#
#                                 AVAILABILITY_365
# ID                                           NaN
# HOST_ID                                      NaN
# LATITUDE                                     NaN
# LONGITUDE                                    NaN
# PRICE                                        NaN
# MINIMUM_NIGHTS                               NaN
# NUMBER_OF_REVIEWS                            NaN
# REVIEWS_PER_MONTH                            NaN
# CALCULATED_HOST_LISTINGS_COUNT               NaN
# AVAILABILITY_365                             1.0

# %%
df[df['ID'].duplicated()].sort_values(by='ID',ascending=True)
# df[df['ID']==2595]
# Out:
# Empty DataFrame
# Columns: [ID, HOST_ID, NEIGHBOURHOOD, LATITUDE, LONGITUDE, ROOM_TYPE, PRICE, MINIMUM_NIGHTS, NUMBER_OF_REVIEWS, LAST_REVIEW, REVIEWS_PER_MONTH, CALCULATED_HOST_LISTINGS_COUNT, AVAILABILITY_365]
# Index: []
